# %%
import pandas as pd
import numpy as np
def get_city_state_bank():
    df = pd.read_csv("/Users/Alexander/Downloads/AdWords API Location Criteria 2015-05-29.csv")
    city_state = []
    for location in df["Canonical Name"].values:
        if location.split(",")[-1] == "United States":
            try:
                city_state.append((location.split(",")[0],location.split(",")[-2]))
            except: IndexError
    return city_state

# %%
import random

# %%
city, state = random.sample(city_state_bank,1)[0]

# %%
print city
print state
# Out:
# 32210
# Florida

# %%
np.random.choice(city_state_bank)

# %%
city_state = np.random.choice(city_state_bank)

# %%
c,s = test[0]

# %%
print c
print s
# Out:
# Anchorage
# Alaska

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/Alexander/Downloads/AdWords API Location Criteria 2015-05-29.csv")

# %%
df.head()
# Out:
#    Criteria ID            Name  \
# 0      1000010       Abu Dhabi
# 1      1000011           Ajman
# 2      1000012          Al Ain
# 3      1000013           Dubai
# 4      1000014  Ras Al-Khaimah
#
#                                       Canonical Name  Parent ID Country Code  \
# 0           Abu Dhabi,Abu Dhabi,United Arab Emirates    9041082           AE
# 1                   Ajman,Ajman,United Arab Emirates    9047096           AE
# 2              Al Ain,Abu Dhabi,United Arab Emirates    9041082           AE
# 3                   Dubai,Dubai,United Arab Emirates    9041083           AE
# 4  Ras Al-Khaimah,Ras al Khaimah,United Arab Emir...    9047098           AE
#
#   Target Type  Status
# 0        City  Active
# 1        City  Active
# 2        City  Active
# 3        City  Active
# 4        City  Active

# %%
df["Canonical Name"].head()
# Out:
# 0             Abu Dhabi,Abu Dhabi,United Arab Emirates
# 1                     Ajman,Ajman,United Arab Emirates
# 2                Al Ain,Abu Dhabi,United Arab Emirates
# 3                     Dubai,Dubai,United Arab Emirates
# 4    Ras Al-Khaimah,Ras al Khaimah,United Arab Emir...
# Name: Canonical Name, dtype: object

# %%
df["Canonical Name"][0].split(",")[-1] == "United States"
# Out:
# 'United Arab Emirates'

# %%
df["Canonical Name"].values[0].split(",")
# Out:
# ['Abu Dhabi', 'Abu Dhabi', 'United Arab Emirates']

# %%
for i, location in enumerate(df["Canonical Name"].values):
    #print location
    if location.split(",")[-1] == "United States":
        print location.split(",")[0]
        print location.split(",")[-2]
# Out:
# Anchorage
# Alaska
# Anderson
# Alaska
# Angoon
# Alaska
# Atqasuk
# Alaska
# Barrow
# Alaska
# Bethel
# Alaska
# Clear
# Alaska
# Cordova
# Alaska
# Craig
# Alaska
# Delta Junction
# Alaska
# Dillingham
# Alaska
# Eagle River
# Alaska
# Eielson Air Force Base
# Alaska
# Elmendorf Air Force Base
# Alaska
# Fairbanks
# Alaska
# Galena
# Alaska
# Girdwood
# Alaska
# Glennallen
# Alaska
# Gustavus
# Alaska
# Haines
# Alaska
# Healy
# Alaska
# Homer
# Alaska
# Hoonah
# Alaska
# Juneau
# Alaska
# Kenai
# Alaska
# Ketchikan
# Alaska
# Klawock
# Alaska
# Kodiak
# Alaska
# Kotzebue
# Alaska
# McGrath
# Alaska
# Metlakatla
# Alaska
# Mountain Village
# Alaska
# Nikiski
# Alaska
# Nome
# Alaska
# North Pole
# Alaska
# Palmer
# Alaska
# Pelican
# Alaska
# Petersburg
# Alaska
# Port Lions
# Alaska
# Seward
# Alaska
# Sitka
# Alaska
# Skagway
# Alaska
# Soldotna
# Alaska
# Saint Paul Island
# Alaska
# Tanacross
# Alaska
# Thorne Bay
# Alaska
# Tok
# Alaska
# Tununak
# Alaska
# Unalaska
# Alaska
# ...

# %%
cities = []
states = []
locations = []
for location in df["Canonical Name"].values:
    if location.split(",")[-1] == "United States":
        try:
            states.append(location.split(",")[-2])
            cities.append(location.split(",")[0])
        except: IndexError

# %%
print len(cities)
print len(states)
# Out:
# 55119
# 55119

# %%
np.unique(states)
# Out:
# array([' AL', ' AR', ' CA', ' FL', ' GA', ' IA', ' ID', ' IL', ' IN',
#        ' KS', ' KY', ' LA', ' MA', ' MD', ' MD)', ' ME', ' MN', ' MO',
#        ' MS', ' MT', ' NC', ' ND', ' NE', ' NH', ' NM', ' NV', ' NY',
#        ' OH', ' OK', ' OR', ' PA', ' SC', ' SD', ' TN', ' TN-VA', ' TX',
#        ' UT', ' VA', ' WA', ' WI', ' WV', 'AK-AT LARGE', 'Alabama',
#        'Alaska', 'Arizona', 'Arkansas', 'Blue Eye', 'California',
#        'Colorado', 'Connecticut', 'DC-AT LARGE', 'DE-AT LARGE', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'IL',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'MT-AT LARGE', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'ND-AT LARGE', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
# ...
