# %% [markdown]
# Real Time Intrusion Detection
# =============================
#
# Nemesis Networks has hired you as a consultant to help build out their
# real time intrusion detection system.
#
# They want to use Kafka to capture all login and logout events in a
# system and then look for patterns.
#
# For example, if there is a marked uptick in login failures the system
# should raise an alert. This way the system can lock out people who are
# trying to hack into the system by guessing passwords.
#
# Step 1
# ------
#
# Using the steps from the lecture:
#
# - Download Kafka
#
# - Install Kafka
#
# - Start Zookeeper and Kafka
#
# Step 2
# ------
#
# Use `pip` to install `kafka-python` and `avro`.
#
# Step 3
# ------
#
# In Kafka create a topic called `login-topic`.

# %% [markdown]
#     KAFKA_TOPIC = 'login-topic'
#
#     OR (?)
#
#     ./bin/kafka-topics.sh \
#       --zookeeper localhost:2181 \
#       --topic login-topic \
#       --create \
#       --replication-factor 1 \
#       --partitions 1

# %% [markdown]
#     ./bin/kafka-topics.sh \
#       --zookeeper localhost:2181 \
#       --topic amazon-topic \
#       --create \
#       --replication-factor 1 \
#       --partitions 1

# %% [markdown]
# Step 4
# ------
#
# Create an Avro schema for objects that look like this.
#
# ```javascript
# {"date":"2015-10-01","time":"08:43:14","user":"alice","op":"login","success":"false"}
# ```
#
# Field      |Value
# -----      |-----
# `date`     |Date in `yyyy-mm-dd` format
# `time`     |Time in `hh:mm:ss` format
# `user`     |Some user ID like `alice` or `bob`
# `op`       |`login` `logout`
# `success`  |`true` `false`

# %% [markdown]
#     AVRO_SCHEMA_STRING = '''{
#         "namespace": "kafda_lab.avro",
#         "type": "record",
#         "name": "User",
#         "fields": [
#             {"name": "date",    "type": "string"},
#             {"name": "time",    "type": "string"},
#             {"name": "user",    "type": "string"},
#             {"name": "op",      "type": "string"},
#             {"name": "success", "type": "string"}
#         ]
#     }
#     '''

# %% [markdown]
# Step 5
# ------
#
# Create a producer that uses the `get_login_event()` function defined
# below to feed events into the Kafka topic `login-topic`. The producer
# should serialize the events using Avro.
#
# ```python
# import random
# import time
#
# LOGIN_USERS = ['alice','bob','chas','dee','eve']
# LOGIN_OPS = ['login','logout']
#
# def get_login_event():
#     return {
#         'date'    : time.strftime('%F'),
#         'time'    : time.strftime('%T'),
#         'user'    : random.choice(LOGIN_USERS),
#         'op'      : random.choice(LOGIN_OPS),
#         'success' : bool(random.randint(0,1)) }
# ```

# %% [markdown]
# Step 6
# ------
#
# Create a consumer that consumes the login events published to
# `login-topic`.
#
# The consumer keeps track of average login success rate. It prints out
# the rate.
#
# The average login success rate is `success/total_count`.
#
# Step 7
# ------

# %%
import io, random, threading, logging, time

import avro.io
import avro.schema

from kafka.client   import KafkaClient
from kafka.consumer import KafkaConsumer
from kafka.producer import SimpleProducer


LOGIN_USERS = ['alice','bob','chas','dee','eve']
LOGIN_OPS = ['login','logout']

KAFKA_TOPIC = 'login-topic'

AVRO_SCHEMA_STRING = '''{
        "namespace": "kafka_lab.avro",
        "type": "record",
        "name": "User",
        "fields": [
            {"name": "date",    "type": "string"},
            {"name": "time",    "type": "string"},
            {"name": "user",    "type": "string"},
            {"name": "op",      "type": "string"},
            {"name": "success", "type": "string"}
        ]
    }
    '''

# %%
class AvroSerDe:
    '''Serializes and deserializes data structures using Avro.'''
    def __init__(self, avro_schema_string):
        self.schema = avro.schema.parse(avro_schema_string)
        self.datum_writer = avro.io.DatumWriter(self.schema)
        self.datum_reader = avro.io.DatumReader(self.schema)

    def obj_to_bytes(self, obj):
        bytes_writer = io.BytesIO()
        encoder = avro.io.BinaryEncoder(bytes_writer)
        self.datum_writer.write(obj, encoder)
        raw_bytes = bytes_writer.getvalue()
        return raw_bytes

    def bytes_to_obj(self, raw_bytes):
        bytes_reader = io.BytesIO(raw_bytes)
        decoder = avro.io.BinaryDecoder(bytes_reader)
        obj = self.datum_reader.read(decoder)
        return obj

# %%
def get_login_event():
    return {
        'date'    : str(time.strftime('%F')),
        'time'    : str(time.strftime('%T')),
        'user'    : random.choice(LOGIN_USERS),
        'op'      : random.choice(LOGIN_OPS),
        'success' : str(bool(random.randint(0,1))) }

class Producer(threading.Thread):
    '''Produces users and publishes them to Kafka topic.'''
    daemon = True
    def run(self):
        avro_serde = AvroSerDe(AVRO_SCHEMA_STRING)
        client = KafkaClient('localhost:9092')
        producer = SimpleProducer(client)
        while True:
            # input generated avro data here
            raw_bytes = avro_serde.obj_to_bytes(get_login_event())
            producer.send_messages(KAFKA_TOPIC, raw_bytes)
            time.sleep(1)
# Out:
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:47'}
# Success Rate 0.45
# Threat Detected!
# 17.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:47'}
# Success Rate 0.49
# Threat Detected!
# 271.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:47'}
# Success Rate 0.49
# Threat Detected!
# 271.0 Failured Login Attempts !--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:47'}
#
#
#
#
# Success Rate 0.47
# Threat Detected!
# 17.0 Failured Login Attempts !

# %%
class Consumer(threading.Thread):
    '''Consumes users from Kafka topic.'''
    daemon = True
    def run(self):
        avro_serde = AvroSerDe(AVRO_SCHEMA_STRING)
        client = KafkaClient('localhost:9092')
        consumer = KafkaConsumer(KAFKA_TOPIC,
                                 group_id='my_group',
                                 bootstrap_servers=['localhost:9092'])
        attempts = 0.0
        success = 0.0
        failure = 0.0
        for message in consumer:
            user = avro_serde.bytes_to_obj(message.value)
            print '--> ' + str(user)
            if user['op'] == 'login':
                attempts += 1.0
                if user['success'] == 'True':
                    success += 1.0
                else:
                    failure += 1.0
            if attempts > 0:
                print "Success Rate {:.2}".format(success/attempts)
            if failure > 3:
                print "Threat Detected!"
                print "{} Failured Login Attempts !".format(failure)
            print "\n\n"

# %%
'''Starts producer and consumer threads.'''
threads = [ Producer(), Consumer() ]
for t in threads: t.start()
time.sleep(5)
# Out:
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:48'}
# Success Rate 0.49
# Threat Detected!
# 271.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:48'}
# Success Rate 0.47
# Threat Detected!
# 17.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:48'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:48'}
#
# Success Rate 0.47--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:48'}
#
#
#
#
# Threat Detected!Success Rate 0.49
#
# 17.0 Failured Login Attempts !Threat Detected!
#
#
#
#
# 271.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:48'}
# Success Rate 1.0
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:48'}
# Success Rate 0.48
# Threat Detected!
# 17.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:48'}
# Success Rate 0.5
# Threat Detected!
# 271.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:45:49'}
# Success Rate 0.5
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:45:49'}
# Success Rate 0.49
# Threat Detected!
# 272.0 Failured Login Attempts !
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:45:49'}
#
# Success Rate 0.47
# Threat Detected!
# 18.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'}
# Success Rate 0.49
# Threat Detected!
# 272.0 Failured Login Attempts !
#  --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'}
#
#
# Success Rate 0.5
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'}
#
# Success Rate 0.47
# Threat Detected!
# 18.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'}
# Success Rate 0.33
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'} --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:49'}
# Success Rate 0.49
# Threat Detected!
# 273.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.46
# Threat Detected!
# 19.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:45:50'}
# Success Rate 0.44
# Threat Detected!
# 20.0 Failured Login Attempts !--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:45:50'}
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:45:50'}Success Rate 0.49
#
#
# Success Rate 0.25Threat Detected!
#
#
#
#
# 274.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:50'}
# Success Rate 0.43
# Threat Detected!--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:50'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:50'}
#
#
# 21.0 Failured Login Attempts !Success Rate 0.2Success Rate 0.49
#
#
#
#
# Threat Detected!Threat Detected!
#
#
# 4.0 Failured Login Attempts !275.0 Failured Login Attempts !
#
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:50'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:50'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:50'}
#
#
# Success Rate 0.2Success Rate 0.49Success Rate 0.43
#
#
# Threat Detected!
# Threat Detected!Threat Detected!4.0 Failured Login Attempts !
#
#
# 275.0 Failured Login Attempts !21.0 Failured Login Attempts !
#
#
#
#
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:51'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:51'}
# Success Rate 0.33--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:51'}
#
# Threat Detected!
# Success Rate 0.454.0 Failured Login Attempts !
#
#
#
# Threat Detected!
#
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:51'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:51'}
# Success Rate 0.33
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:51'}
# Success Rate 0.45
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:51'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:51'}
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:51'}
#
# Success Rate 0.45
#
#
# Threat Detected!Success Rate 0.33
#
# 21.0 Failured Login Attempts !Threat Detected!
#
#
#
# 4.0 Failured Login Attempts !
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:45:52'}
#  Success Rate 0.45--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:45:52'}
#
# Threat Detected!--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:45:52'}Success Rate 0.33
#
#
# 21.0 Failured Login Attempts !Success Rate 0.49Threat Detected!
#
#
#
#
# Threat Detected!
#
# 4.0 Failured Login Attempts !275.0 Failured Login Attempts !
#
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:52'}
# Success Rate 0.45
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:52'}
# Success Rate 0.33
# Threat Detected!--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:52'}
#
# 4.0 Failured Login Attempts !Success Rate 0.49
#
#
#
#
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:52'}
# Success Rate 0.45
# Threat Detected!--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:52'}
# Success Rate 0.33
# Threat Detected!
#
# 4.0 Failured Login Attempts !21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:52'}
#
#
#
#
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:53'}
# Success Rate 0.45
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:53'}
# Success Rate 0.33
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:45:53'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}
#  --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}Success Rate 0.45--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}
#
#
# Success Rate 0.49Threat Detected!Success Rate 0.33
#
# Threat Detected!
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# 21.0 Failured Login Attempts !
#
#
#
#
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}
# Success Rate 0.43
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}
# Success Rate 0.46
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:45:53'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
#  Success Rate 0.5--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.47
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
# Success Rate 0.49
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
# Success Rate 0.47
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
# Success Rate 0.5
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:54'}
#
#
# Success Rate 0.5
# Threat Detected!
# 275.0 Failured Login Attempts !
#
#
#
# Success Rate 0.49
# Threat Detected!
# 21.0 Failured Login Attempts !
#
#
#
# Success Rate 0.56
# Threat Detected!
# 4.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:55'}
# Success Rate 0.48
# Threat Detected!
# 22.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:55'}
# Success Rate 0.5
# Threat Detected!
# 5.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:45:55'}
# Success Rate 0.49
# Threat Detected!
# 276.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:55'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:55'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:55'}
#
#
# Success Rate 0.49
# Threat Detected!
# Success Rate 0.48
# Threat Detected!
# 22.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 5.0 Failured Login Attempts !
#
#
#
# 276.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:55'}
# Success Rate 0.55
# Threat Detected!
# 5.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:55'}
# Success Rate 0.49
# Threat Detected!
# 22.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:55'}
# Success Rate 0.5
# Threat Detected!
# 276.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
#  --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
# Success Rate 0.5
# Threat Detected!
# 276.0 Failured Login Attempts !
#
#
#
# Success Rate 0.49
# Threat Detected!
# 22.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
# Success Rate 0.55
# Threat Detected!
# 5.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
# Success Rate 0.49
# Threat Detected!
# 277.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
# Success Rate 0.5
# Threat Detected!
# 6.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:45:56'}
# Success Rate 0.48
# Threat Detected!
# 23.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:56'}
# Success Rate 0.49
# Threat Detected!
# 23.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:56'}
#  Success Rate 0.5--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:56'}
# Success Rate 0.54
# Threat Detected!
# 6.0 Failured Login Attempts !
#
#
#
#
# Threat Detected!
# 277.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
# Success Rate 0.54
# Threat Detected!
# 6.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
# Success Rate 0.5
# Threat Detected!
# 277.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
# Success Rate 0.49
# Threat Detected!
# 23.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
# Success Rate 0.57
# Threat Detected!
# 6.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
# Success Rate 0.5--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:45:57'}
#
# Threat Detected!
# 277.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 23.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:57'}
# Success Rate 0.57
# Threat Detected!
# 6.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:57'}
# Success Rate 0.5
# Threat Detected!
# 23.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:45:57'}
# Success Rate 0.5
# Threat Detected!
# 277.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:45:58'}
# Success Rate 0.53
# Threat Detected!
#  --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:45:58'}
# Success Rate 0.49
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:45:58'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:58'}
# Success Rate 0.49
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:58'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'True', u'time': u'23:45:58'}
# Success Rate 0.53
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:58'}
# Success Rate 0.49--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:58'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:45:58'}
#
# Success Rate 0.53
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.5
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.56
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.5
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.56
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.51
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.59
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:45:59'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:00'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:00'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:00'}
#
#
# Success Rate 0.59
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# Success Rate 0.51
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:46:00'}
# Success Rate 0.51
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:46:00'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'False', u'time': u'23:46:00'}
# Success Rate 0.59
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:46:00'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:46:00'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'True', u'time': u'23:46:00'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:01'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:01'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:01'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:01'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:01'}
#  --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:01'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:02'}
# Success Rate 0.61
#  Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:02'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:02'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:02'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:46:03'}
# Success Rate 0.52
# Threat Detected!
# 24.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:46:03'}
# Success Rate 0.61
# Threat Detected!
# 7.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'chas', u'success': u'True', u'time': u'23:46:03'}
# Success Rate 0.5
# Threat Detected!
# 278.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:03'}
# Success Rate 0.51
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:03'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:03'}
# Success Rate 0.58
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:03'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:03'}
#
# Success Rate 0.6--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:03'}Success Rate 0.52
#
#
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.53
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.62
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:04'}
# Success Rate 0.53
#  --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:04'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:04'}
# Success Rate 0.62
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.64
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:04'}
# Success Rate 0.54
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:05'}
# Success Rate 0.55
# Threat Detected!
# 25.0 Failured Login Attempts !--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:05'}
#
# Success Rate 0.65
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:05'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:05'}
# Success Rate 0.55
# Threat Detected!
# 25.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:05'}
# Success Rate 0.67
# Threat Detected!
# 8.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'True', u'time': u'23:46:05'}
# Success Rate 0.5
# Threat Detected!
# 279.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:05'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:05'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:05'}
#
#
# Success Rate 0.64
# Threat Detected!
# 9.0 Failured Login Attempts !
#
#
#
# Success Rate 0.54
# Threat Detected!
# 26.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 280.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.64
# Threat Detected!
# 9.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.5
# Threat Detected!
# 280.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.54
# Threat Detected!
# 26.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.5
# Threat Detected!
# 280.0 Failured Login Attempts !
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.64
# Threat Detected!
# 9.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:06'}
# Success Rate 0.54
# Threat Detected!
# 26.0 Failured Login Attempts !
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:06'}
# Success Rate 0.62
# Threat Detected!
# 10.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:06'}
# Success Rate 0.5
# Threat Detected!
# 281.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:06'}
# Success Rate 0.53
# Threat Detected!
# 27.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:07'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:07'}
#
# Success Rate 0.5--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'False', u'time': u'23:46:07'}Success Rate 0.59
# Threat Detected!
# 282.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.53
# Threat Detected!
# 28.0 Failured Login Attempts !
#
#
#
#
# Threat Detected!
# 11.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:07'}
# Success Rate 0.53
# Threat Detected!
# 28.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:07'}
# Success Rate 0.59
# Threat Detected!
# 11.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:07'}
# Success Rate 0.5
# Threat Detected!
# 282.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:07'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:07'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:07'}
# Success Rate 0.53
# Threat Detected!
# 28.0 Failured Login Attempts !
#
#
#
#
#
# Success Rate 0.59
# Threat Detected!Success Rate 0.5
#
# 11.0 Failured Login Attempts !Threat Detected!
# 282.0 Failured Login Attempts !
#
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.5
# Threat Detected!
# 283.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.57
# Threat Detected!
# 12.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.52
# Threat Detected!
# 29.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:08'}
#  Success Rate 0.52--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:08'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'True', u'time': u'23:46:08'}
# Success Rate 0.5
# Threat Detected!
# 283.0 Failured Login Attempts !
#
#
#
#
# Threat Detected!
# 29.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.59
# Threat Detected!
# 12.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.5
# Threat Detected!
# 283.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.59
# Threat Detected!
# 12.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'False', u'time': u'23:46:08'}
# Success Rate 0.52
# Threat Detected!
# 29.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:09'}
# Success Rate 0.57
# Threat Detected!
# 13.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:09'} --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'eve', u'success': u'False', u'time': u'23:46:09'}
# Success Rate 0.52
# Threat Detected!
# 30.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.5
# Threat Detected!
# 284.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:09'}
# Success Rate 0.52
# Threat Detected!
# 30.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:09'}
# Success Rate 0.5
# Threat Detected!
# 284.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'alice', u'success': u'True', u'time': u'23:46:09'}
# Success Rate 0.57
# Threat Detected!
# 13.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:09'}
# Success Rate 0.52
# Threat Detected!--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:09'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'dee', u'success': u'False', u'time': u'23:46:09'}
# Success Rate 0.5
# Threat Detected!
# 284.0 Failured Login Attempts !
#
#
#
#
# 30.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.57
# Threat Detected!
# 13.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.55
# Threat Detected!
# 14.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.51
# Threat Detected!
# 31.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'dee', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.5
# Threat Detected!
# 285.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'True', u'time': u'23:46:10'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'True', u'time': u'23:46:10'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'True', u'time': u'23:46:10'}
#
#
# Success Rate 0.55Success Rate 0.5
# Success Rate 0.51
# Threat Detected!
# Threat Detected!
#
# Threat Detected!14.0 Failured Login Attempts !285.0 Failured Login Attempts !
#
#
#
#
# 31.0 Failured Login Attempts !
#
#
#
#
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.5
# Threat Detected!
# 32.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.5
# Threat Detected!
# 286.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'bob', u'success': u'False', u'time': u'23:46:10'}
# Success Rate 0.53
# Threat Detected!
# 15.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:11'}
#  Success Rate 0.5--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:11'}--> {u'date': u'2015-10-07', u'op': u'login', u'user': u'alice', u'success': u'False', u'time': u'23:46:11'}
# Threat Detected!
# 287.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.52
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
#
# Success Rate 0.49
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:46:11'}
# Success Rate 0.53
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:46:11'}
# Success Rate 0.5
# Threat Detected!
# 287.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'login', u'user': u'chas', u'success': u'True', u'time': u'23:46:11'}
# Success Rate 0.5
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:11'}
# Success Rate 0.53
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:11'}
# Success Rate 0.5
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:11'}
# Success Rate 0.5
# Threat Detected!
# 287.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:12'}
# Success Rate 0.53--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:12'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'False', u'time': u'23:46:12'}
#
#
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 287.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:12'}
# Success Rate 0.53
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:12'}
# Success Rate 0.5
# Threat Detected!
# 287.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'bob', u'success': u'False', u'time': u'23:46:12'}
# Success Rate 0.5
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:12'}--> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:12'}
#
# Success Rate 0.53
# Threat Detected!
# 16.0 Failured Login Attempts !
#
#
#
# Success Rate 0.5
# Threat Detected!
# 33.0 Failured Login Attempts !
#
#
#
# --> {u'date': u'2015-10-07', u'op': u'logout', u'user': u'eve', u'success': u'True', u'time': u'23:46:12'}
# Success Rate 0.5
# Threat Detected!
# 287.0 Failured Login Attempts !

# %% [markdown]
# Suppose you had the data from all the servers coming into your Kafka
# topic. How would you scale it?

# %% [markdown]
# Suppose you scale this with hundreds of consumers. What might some of
# the issues be? How can you resolve those issues?
