# %%
# script that will find the 20 most freq words in the sonnet file 
# then upload results into a new S3 bucket

# %%
import boto
import nltk

# %%
# connect to AWS
s3 = boto.connect_s3(aws_access_key_id ="AKIAIBZEDBZIIV7PUW5Q", 
                     aws_secret_access_key="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")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-093d711f9d51> in <module>()
#       1 # connect to AWS
# ----> 2 s3 = boto.connect_s3(aws_access_key_id ="AKIAIBZEDBZIIV7PUW5Q",
#       3                      aws_secret_access_key="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")
#
# NameError: name 'boto' is not defined

# %%
# List all the buckets
all_buckets = [b.name for b in conn.get_all_buckets()]
print all_buckets
# Out:
# [u'data6007', u'sonnet_bucket']

# %%
# Check if bucket exist. If exist get bucket, else create one
bucket_name = 'sonnet_bucket'

if conn.lookup(bucket_name) is None:
    b = conn.create_bucket(bucket_name, policy='public-read')
else:
    b = conn.get_bucket(bucket_name)

# %%
bucket = conn.lookup('data6007')

# %%
bucket.

# %%
file_ = b.new_key('shakespeare-sonnets.txt')

# %%
# upload file into data6007 bucket
bucket = conn.lookup('data6007')
file_ = bucket.new_key('shakespeare-sonnets.txt')
file_.set_contents_from_filename("/Users/Alexander/shakespeare-sonnets.txt")
# Out:
# 95726

# %%
file_.get_contents_as_string()
# Out:
# "THE SONNETS\nby William Shakespeare\n\nI\n\nFrom fairest creatures we desire increase,\nThat thereby beauty's rose might never die,\nBut as the riper should by time decease,\nHis tender heir might bear his memory:\nBut thou contracted to thine own bright eyes,\nFeed'st thy light's flame with self-substantial fuel,\nMaking a famine where abundance lies,\nThy self thy foe, to thy sweet self too cruel:\nThou that art now the world's fresh ornament,\nAnd only herald to the gaudy spring,\nWithin thine own bud buriest thy content,\nAnd tender churl mak'st waste in niggarding:\n  Pity the world, or else this glutton be,\n  To eat the world's due, by the grave and thee.\n\nII\n\nWhen forty winters shall besiege thy brow,\nAnd dig deep trenches in thy beauty's field,\nThy youth's proud livery so gazed on now,\nWill be a tatter'd weed of small worth held: \nThen being asked, where all thy beauty lies,\nWhere all the treasure of thy lusty days; \nTo say, within thine own deep sunken eyes,\nWer
# ...

# %%
# upload file into sonnet_bucket
new_file = "/Users/Alexander/shakespeare-sonnets.txt"
file_object.set_contents_from_filename(new_file)
# Out:
# 95726

# %%
# Read from file
print file_object.get_contents_as_string()
# Out:
# THE SONNETS
# by William Shakespeare
#
# I
#
# From fairest creatures we desire increase,
# That thereby beauty's rose might never die,
# But as the riper should by time decease,
# His tender heir might bear his memory:
# But thou contracted to thine own bright eyes,
# Feed'st thy light's flame with self-substantial fuel,
# Making a famine where abundance lies,
# Thy self thy foe, to thy sweet self too cruel:
# Thou that art now the world's fresh ornament,
# And only herald to the gaudy spring,
# Within thine own bud buriest thy content,
# And tender churl mak'st waste in niggarding:
#   Pity the world, or else this glutton be,
#   To eat the world's due, by the grave and thee.
#
# II
#
# When forty winters shall besiege thy brow,
# And dig deep trenches in thy beauty's field,
# Thy youth's proud livery so gazed on now,
# Will be a tatter'd weed of small worth held:
# Then being asked, where all thy beauty lies,
# Where all the treasure of thy lusty days;
# ...

# %%
# Print all the files in the bucket
filenames = [f.name for f in b.list()]
print filenames
# Out:
# [u'shakespeare-sonnets.txt', u'sonnet_freq_words.txt']

# %%
# Delete all files in bucket
for file_ in b.get_all_keys():
    b.delete_key(file_)

# %%
# Print all the files in the bucket
filenames = [f.name for f in b.list()]
print filenames
# Out:
# []

# %%
# Delete Bucket
# Must delete all files in bucket
# Before deleting bucket
conn.delete_bucket('sonnet_bucket')

# %%
# List all the buckets
all_buckets = [b.name for b in conn.get_all_buckets()]
print all_buckets
# Out:
# [u'data6007']

# %%
# Delete a file
a = b.new_key('somefilename')
a.delete()
# Out:
# ---------------------------------------------------------------------------
# S3ResponseError                           Traceback (most recent call last)
# <ipython-input-13-c34085af741c> in <module>()
#       1 # Delete a file
#       2 a = b.new_key('somefilename')
# ----> 3 a.delete()
#
# //anaconda/lib/python2.7/site-packages/boto/s3/key.pyc in delete(self, headers)
#     542         """
#     543         return self.bucket.delete_key(self.name, version_id=self.version_id,
# --> 544                                       headers=headers)
#     545
#     546     def get_metadata(self, name):
#
# //anaconda/lib/python2.7/site-packages/boto/s3/bucket.pyc in delete_key(self, key_name, headers, version_id, mfa_token)
#     760                                          version_id=version_id,
#     761                                          mfa_token=mfa_token,
# --> 762                                          query_args_l=None)
#     763
# ...

# %% [markdown]
# ####Write a program that reads the file from S3.

# %%
# create bucket object
bucket_name = 'data6007'
bucket = conn.get_bucket(bucket_name)

# %%
sonnets = bucket.get_key("shakespeare-sonnets.txt")

# %%
sonnets.get_contents_as_string()
# Out:
# "THE SONNETS\nby William Shakespeare\n\nI\n\nFrom fairest creatures we desire increase,\nThat thereby beauty's rose might never die,\nBut as the riper should by time decease,\nHis tender heir might bear his memory:\nBut thou contracted to thine own bright eyes,\nFeed'st thy light's flame with self-substantial fuel,\nMaking a famine where abundance lies,\nThy self thy foe, to thy sweet self too cruel:\nThou that art now the world's fresh ornament,\nAnd only herald to the gaudy spring,\nWithin thine own bud buriest thy content,\nAnd tender churl mak'st waste in niggarding:\n  Pity the world, or else this glutton be,\n  To eat the world's due, by the grave and thee.\n\nII\n\nWhen forty winters shall besiege thy brow,\nAnd dig deep trenches in thy beauty's field,\nThy youth's proud livery so gazed on now,\nWill be a tatter'd weed of small worth held: \nThen being asked, where all thy beauty lies,\nWhere all the treasure of thy lusty days; \nTo say, within thine own deep sunken eyes,\nWer
# ...

# %% [markdown]
# ####Calculate the frequencies of all the words in the file.
#     Sort the words in descending order of frequency.
#     Print out the 20 most frequently used words and their frequencies.

# %%
tokens = nltk.tokenize.regexp_tokenize(sonnets.get_contents_as_string(), r'[\w\']+')

# %%
tokens[:10]
# Out:
# ['THE',
#  'SONNETS',
#  'by',
#  'William',
#  'Shakespeare',
#  'I',
#  'From',
#  'fairest',
#  'creatures',
#  'we']

# %%
from collections import Counter
import numpy as np
import panda as pd

# %%
# FreqDist automatically sorts according to freq count
token_freq = nltk.FreqDist(tokens)
#20 most frequently used words and their frequencies.
token_freq.most_common(20)
# Out:
# [('the', 358),
#  ('of', 350),
#  ('my', 342),
#  ('I', 342),
#  ('to', 335),
#  ('in', 287),
#  ('thy', 251),
#  ('and', 248),
#  ('And', 242),
#  ('that', 239),
#  ('thou', 209),
#  ('with', 163),
#  ('me', 162),
#  ('thee', 161),
#  ('is', 157),
#  ('not', 156),
#  ('love', 155),
#  ('a', 147),
#  ('be', 132),
#  ('all', 110)]

# %% [markdown]
# ####Upload the calculated and sorted frequencies for all the words to S3

# %%
Counter(tokens)
# Out:
# Counter({'the': 358, 'of': 350, 'my': 342, 'I': 342, 'to': 335, 'in': 287, 'thy': 251, 'and': 248, 'And': 242, 'that': 239, 'thou': 209, 'with': 163, 'me': 162, 'thee': 161, 'is': 157, 'not': 156, 'love': 155, 'a': 147, 'be': 132, 'all': 110, 'his': 104, 'you': 104, 'it': 98, 'for': 98, 'so': 98, 'this': 95, 'But': 89, 'your': 87, 'That': 83, 'doth': 82, 'as': 81, 'do': 80, 'by': 80, 'To': 80, 'The': 79, 'on': 74, 'but': 74, 'For': 73, 'have': 69, 'from': 68, 'are': 66, 'their': 62, 'which': 61, 'no': 60, 'more': 59, 'When': 57, 'what': 56, 'mine': 53, 'eyes': 52, 'heart': 51, 'sweet': 51, 'will': 51, 'beauty': 50, 'O': 50, 'when': 49, 'art': 49, 'shall': 49, 'So': 47, 'Which': 47, 'her': 47, 'self': 45, 'should': 44, 'they': 42, 'then': 41, 'fair': 41, 'can': 41, 'or': 41, 'thine': 40, 'time': 40, 'As': 40, 'still': 39, 'one': 38, 'true': 38, 'Or': 38, 'hath': 37, 'make': 37, 'eye': 37, 'now': 36, 'In': 36, 'him': 36, 'he': 36, 'than': 35, 'see': 35, 'if': 34, 'If': 34, 'am': 34, 'T
# ...

# %%
import pandas as pd
df = pd.DataFrame(tokens_2.most_common(20))
df.to_csv(new_file_2 , index=False)

# %%
df2 = pd.read_csv(new_file_2)

# %%
df2
# Out:
#        0    1
# 0    the  358
# 1     of  350
# 2     my  342
# 3      I  342
# 4     to  335
# 5     in  287
# 6    thy  251
# 7    and  248
# 8    And  242
# 9   that  239
# 10  thou  209
# 11  with  163
# 12    me  162
# 13  thee  161
# 14    is  157
# 15   not  156
# 16  love  155
# 17     a  147
# 18    be  132
# 19   all  110

# %%
new_file_2 = "/Users/Alexander/Documents/6007_Data_Engineering/AWS_Exercise_20_most_common_words.txt"
file = bucket.new_key(key_name = new_file)

# %%
bucket.get_all_keys()
# Out:
# [<Key: data6007,pos/cv000_29590.txt>,
#  <Key: data6007,pos/cv001_18431.txt>,
#  <Key: data6007,pos/cv002_15918.txt>,
#  <Key: data6007,pos/cv003_11664.txt>,
#  <Key: data6007,pos/cv004_11636.txt>,
#  <Key: data6007,pos/cv005_29443.txt>,
#  <Key: data6007,pos/cv006_15448.txt>,
#  <Key: data6007,pos/cv007_4968.txt>,
#  <Key: data6007,pos/cv008_29435.txt>,
#  <Key: data6007,pos/cv009_29592.txt>,
#  <Key: data6007,pos/cv010_29198.txt>,
#  <Key: data6007,pos/cv011_12166.txt>,
#  <Key: data6007,pos/cv012_29576.txt>,
#  <Key: data6007,pos/cv013_10159.txt>,
#  <Key: data6007,pos/cv014_13924.txt>,
#  <Key: data6007,pos/cv015_29439.txt>,
#  <Key: data6007,pos/cv016_4659.txt>,
#  <Key: data6007,pos/cv017_22464.txt>,
#  <Key: data6007,pos/cv018_20137.txt>,
#  <Key: data6007,pos/cv019_14482.txt>,
#  <Key: data6007,pos/cv020_8825.txt>,
#  <Key: data6007,pos/cv021_15838.txt>,
#  <Key: data6007,pos/cv022_12864.txt>,
#  <Key: data6007,pos/cv023_12672.txt>,
#  <Key: data6007,pos/cv024_6778.txt>,
# ...

# %%
# Delete Bucket
# Must delete all files in bucket
# Before deleting bucket
conn.delete_bucket('galvanizebucket')

# %%
# new script that will find the 20 most freq words in the sonnet file 
# then upload results into a new S3 bucket
